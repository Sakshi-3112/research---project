# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Create dataset
data = {
    "Name": ["Aman", "Riya", "Sohan", "Priya", "Rahul"],
    "Maths": [85, 78, 90, 88, 76],
    "Science": [80, 82, 85, 89, 75],
    "English": [78, 74, 88, 90, 70]
}

df = pd.DataFrame(data)

# %%
print("Student Data:\n")
print(df)
# Out:
# Student Data:
#
#     Name  Maths  Science  English
# 0   Aman     85       80       78
# 1   Riya     78       82       74
# 2  Sohan     90       85       88
# 3  Priya     88       89       90
# 4  Rahul     76       75       70

# %%
# Step 3: Calculate Average Marks
df["Average"] = df[["Maths", "Science", "English"]].mean(axis=1)
print("\nAverage Marks:\n")
print(df[["Name", "Average"]])
# Out:
# Average Marks:
#
#     Name    Average
# 0   Aman  81.000000
# 1   Riya  78.000000
# 2  Sohan  87.666667
# 3  Priya  89.000000
# 4  Rahul  73.666667

# %%
topper = df.loc[df["Average"].idxmax()]
print("\nTopper Student:")
print(topper)
# Out:
# Topper Student:
# Name       Priya
# Maths         88
# Science       89
# English       90
# Average     89.0
# Name: 3, dtype: object

# %%
# Step 5: Plot Graph
plt.bar(df["Name"], df["Average"])
plt.xlabel("Students")
plt.ylabel("Average Marks")
plt.title("Student Performance Analysis")
plt.show()
